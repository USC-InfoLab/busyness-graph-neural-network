# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
labels = ["BysGNN's Original Adjacency Matrix", "Attention Matrix", "Spatial Similarities Matrix", "Semantics Similarity Matrix"]

MAEs = [6.673, 7.033, 8.050, 7.830]
MAPEs = [0.455, 0.505, 0.560, 0.562]
RMSEs = [13.962, 15.677, 19.436, 17.463]

# %%
# Combine the metrics into a single dataframe
data = {"Adjacency Matrix": labels, "MAE": MAEs, "MAPE": MAPEs, "RMSE": RMSEs}
df = pd.DataFrame(data)
df
# Out:
#                      Adjacency Matrix    MAE   MAPE    RMSE
# 0  BysGNN's Original Adjacency Matrix  6.673  0.455  13.962
# 1                    Attention Matrix  7.033  0.505  15.677
# 2         Spatial Similarities Matrix  8.050  0.560  19.436
# 3         Semantics Similarity Matrix  7.830  0.562  17.463

# %%
# Set the color palette
colors = ["#2ecc71", "#3498db", "#e74c3c"]

# Plotting the bar chart with a logarithmic scale for MAPE
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))
ax = sns.barplot(x="Adjacency Matrix", y="Value", hue="Metric", data=df_melted, palette=colors)

# Setting a logarithmic scale for the y-axis
ax.set_yscale('log')

# Adding labels and title
plt.xlabel('Adjacency Matrices')
plt.ylabel('Metric Values (log scale)')
plt.title('Evaluation Metrics for Different Adjacency Matrices')

# Customizing the legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='upper right')

# Adjusting the y-axis limits
plt.ylim(0.1, 100)



# Adjusting the layout to avoid overlapping labels
plt.tight_layout()

# %%
# Set the color palette
colors = ["#2ecc71", "#3498db", "#e74c3c"]

# Plotting the grouped bar chart
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="Metric", y="Value", hue="Adjacency Matrix", data=df_melted, palette=colors)

# Adding labels and title
plt.xlabel('Metrics')
plt.ylabel('Metric Values')
# plt.title('Evaluation Metrics for Different Adjacency Matrices')

# Customizing the legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='upper right')

# Adjusting the layout to avoid overlapping labels
plt.tight_layout()

# %%
# Define a custom color palette with four colors
colors = ["#2ecc71", "#3498db", "#e74c3c", "#f39c12"]

# Plotting the grouped bar chart
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="Metric", y="Value", hue="Adjacency Matrix", data=df_melted, palette=colors)

# Adding labels and title
plt.xlabel('Metrics')
plt.ylabel('Metric Values')
# plt.title('Evaluation Metrics for Different Adjacency Matrices')

# Customizing the legend
handles, labels = ax.get_legend_handles_labels()
# Adjust the legend position to avoid overlap with RMSE
plt.legend(handles, labels, loc='upper left')

# Set the y-axis scale with base 2 logarithmic scale
ax.set_yscale('log', base=2)

# Format y-axis tick labels as power of 2
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))



# yticks = [0, 5, 10, 15]
# plt.yticks(yticks)

# Adjusting the layout to avoid overlapping labels
plt.tight_layout()

# Increase the font size of x-tick labels for better readability
plt.xticks(fontsize=10)


# Show the plot
plt.savefig('img/eval_adjacency.pdf', format='pdf', dpi=300, bbox_inches='tight', transparent=True)

# %%
# Define a custom color palette with four colors
colors = ["#2ecc71", "#3498db", "#e74c3c", "#f39c12"]

# Plotting the grouped bar chart
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = sns.barplot(x="Metric", y="Value", hue="Adjacency Matrix", data=df_melted, palette=colors)

# Adding labels and title
plt.xlabel('Metrics')
plt.ylabel('Metric Values')
plt.title('Evaluation Metrics for Different Adjacency Matrices')

# Customizing the legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles, labels, loc='upper right')

# Adjusting the layout to avoid overlapping labels
plt.tight_layout()

# Increase the font size of x-tick labels for better readability
plt.xticks(fontsize=10)

# Add annotations for all bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.3f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# Show the plot
plt.show()
